# %% [markdown]
# # Intro to Recommender Systems Lab
#
# Complete the exercises below to solidify your knowledge and understanding of recommender systems.
#
# For this lab, we are going to be putting together a user similarity based recommender system in a step-by-step fashion. Our data set contains customer grocery purchases, and we will use similar purchase behavior to inform our recommender system. Our recommender system will generate 5 recommendations for each customer based on the purchases they have made.

# %%
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# %%
data = pd.read_csv('../data/customer_product_sales.csv')
data.columns = data.columns.str.lower()

# %%
data.head()
# Out:
#    customerid firstname   lastname  salesid  productid           productname  \
# 0       61288      Rosa   Andersen   134196        229  Bread - Hot Dog Buns
# 1       77352     Myron     Murray  6167892        229  Bread - Hot Dog Buns
# 2       40094     Susan  Stevenson  5970885        229  Bread - Hot Dog Buns
# 3       23548    Tricia    Vincent  6426954        229  Bread - Hot Dog Buns
# 4       78981     Scott      Burch   819094        229  Bread - Hot Dog Buns
#
#    quantity
# 0        16
# 1        20
# 2        11
# 3         6
# 4        20

# %% [markdown]
# ## Step 1: Create a data frame that contains the total quantity of each product purchased by each customer.
#
# You will need to group by CustomerID and ProductName and then sum the Quantity field.

# %%
totalq=data.groupby(['customerid','productname'],as_index=False)['quantity'].sum()

# %%
totalq
# Out:
#        customerid                    productname  quantity
# 0              33               Apricots - Dried         1
# 1              33              Assorted Desserts         1
# 2              33        Bandage - Flexible Neon         1
# 3              33  Bar Mix - Pina Colada, 355 Ml         1
# 4              33         Beans - Kidney, Canned         1
# ...           ...                            ...       ...
# 63623       98200                   Vol Au Vents        50
# 63624       98200                  Wasabi Powder        25
# 63625       98200       Wine - Fume Blanc Fetzer        25
# 63626       98200  Wine - Hardys Bankside Shiraz        25
# 63627       98200        Yogurt - French Vanilla        25
#
# [63628 rows x 3 columns]

# %% [markdown]
# ## Step 2: Use the `pivot_table` method to create a product by customer matrix.
#
# The rows of the matrix should represent the products, the columns should represent the customers, and the values should be the quantities of each product purchased by each customer. You will also need to replace nulls with zeros, which you can do using the `fillna` method.

# %%
product_customer = data.pivot_table(index = 'customerid', columns = 'productname', values = 'quantity', fill_value=0)

# %%
product_customer.head(10)
# Out:
# productname  Anchovy Paste - 56 G Tube  Appetizer - Mini Egg Roll, Shrimp  \
# customerid
# 33                                   0                                  0
# 200                                  0                                  0
# 264                                  0                                  0
# 356                                  0                                  0
# 412                                  0                                  0
# 464                                  0                                  0
# 477                                  0                                  0
# 639                                  1                                  0
# 649                                  0                                  0
# 669                                  0                                  0
#
# productname  Appetizer - Mushroom Tart  Appetizer - Sausage Rolls  \
# customerid
# ...

# %% [markdown]
# ## Step 3: Create a customer similarity matrix using `squareform` and `pdist`. For the distance metric, choose "euclidean."

# %%
dist_eucl = 1 / (1 + squareform(pdist(product_customer, metric='euclidean')))

# %%
distance = pd.DataFrame(dist_eucl, index=product_customer.index, columns=product_customer.index)

# %%
distance.head(10)
# Out:
# customerid     33        200       264       356       412       464    \
# customerid
# 33          1.000000  0.085297  0.093953  0.091747  0.087410  0.089695
# 200         0.085297  1.000000  0.085638  0.085297  0.080070  0.083020
# 264         0.093953  0.085638  1.000000  0.088152  0.089301  0.087047
# 356         0.091747  0.085297  0.088152  1.000000  0.085983  0.086688
# 412         0.087410  0.080070  0.089301  0.085983  1.000000  0.085638
# 464         0.089695  0.083020  0.087047  0.086688  0.085638  1.000000
# 477         0.085297  0.084959  0.085638  0.085983  0.085638  0.085638
# 639         0.088913  0.083651  0.086333  0.091325  0.089301  0.092610
# 649         0.088152  0.085638  0.087047  0.085983  0.084959  0.087779
# 669         0.089695  0.087047  0.087047  0.087410  0.087779  0.087047
#
# customerid     477       639       649       669    ...     97697     97753  \
# customerid                                          ...
# ...

# %% [markdown]
# ## Step 4: Check your results by generating a list of the top 5 most similar customers for a specific CustomerID.

# %%
selected_customer = 33
similar = distance[selected_customer].sort_values(ascending = False)[1:6]

# %%
similar
# Out:
# customerid
# 3909    0.095358
# 264     0.093953
# 3531    0.093953
# 2503    0.093498
# 3305    0.093051
# Name: 33, dtype: float64

# %% [markdown]
# ## Step 5: From the data frame you created in Step 1, select the records for the list of similar CustomerIDs you obtained in Step 4.

# %%
similar_ids = similar.index.to_list()
print(similar_ids)
# Out:
# [3909, 264, 3531, 2503, 3305]

# %%
#Obtaining products/quantity from  totalq DF
similarproducts = totalq[totalq.customerid.isin(similar_ids)]
similarproducts
# Out:
#       customerid                     productname  quantity
# 131          264               Apricots - Halves         1
# 132          264                  Apricots Fresh         1
# 133          264      Bacardi Breezer - Tropical         1
# 134          264                   Bagel - Plain         1
# 135          264                 Banana - Leaves         1
# ...          ...                             ...       ...
# 3263        3909    Wine - Charddonnay Errazuriz         2
# 3264        3909        Wine - Fume Blanc Fetzer         1
# 3265        3909  Wine - Magnotta, Merlot Sr Vqa         1
# 3266        3909             Wine - Toasted Head         1
# 3267        3909        Wine - Valpolicella Masi         1
#
# [282 rows x 3 columns]

# %% [markdown]
# ## Step 6: Aggregate those customer purchase records by ProductName, sum the Quantity field, and then rank them in descending order by quantity.
#
# This will give you the total number of each product purchased by the 5 most similar customers to the customer you selected in order from most purchased to least.

# %%
rankedproducts = similarproducts.groupby('productname', as_index=False)['quantity'].sum().sort_values(by = 'quantity', ascending=False)
rankedproducts
# Out:
#                        productname  quantity
# 157               Salsify, Organic         4
# 151                Quiche Assorted         3
# 58                Chocolate - Dark         3
# 215   Wine - Charddonnay Errazuriz         3
# 13                        Bay Leaf         3
# ..                             ...       ...
# 89        Gatorade - Xfactor Berry         1
# 91   Gloves - Goldtouch Disposable         1
# 92                 Grouper - Fresh         1
# 95                Hinge W Undercut         1
# 234        Yogurt - French Vanilla         1
#
# [235 rows x 2 columns]

# %% [markdown]
# ## Step 7: Filter the list for products that the chosen customer has not yet purchased and then recommend the top 5 products with the highest quantities that are left.
#
# - Merge the ranked products data frame with the customer product matrix on the ProductName field.
# - Filter for records where the chosen customer has not purchased the product.
# - Show the top 5 results.

# %%
customer_purchases = totalq[['productname','quantity']][totalq['customerid']==selected_customer]
customer_purchases = [a[1][0] for a in customer_purchases.iterrows()] #list with products the selected customer has purchased

products_to_recommend = rankedproducts[['productname','quantity']]
products_to_recommend = [a[1][0] for a in products_to_recommend.iterrows()] #list with products to recommend

#comparing the products to recommend vs customer purchases, if customer has bought the product to recommend we don't recommend it
products_recommended = [product for product in products_to_recommend if product not in customer_purchases][:5]
products_recommended
# Out:
# ['Chocolate - Dark',
#  'Wine - Charddonnay Errazuriz',
#  'Bay Leaf',
#  'Oranges - Navel, 72',
#  'Wine - Ej Gallo Sierra Valley']

# %% [markdown]
# ## Step 8: Now that we have generated product recommendations for a single user, put the pieces together and iterate over a list of all CustomerIDs.
#
# - Create an empty dictionary that will hold the recommendations for all customers.
# - Create a list of unique CustomerIDs to iterate over.
# - Iterate over the customer list performing steps 4 through 7 for each and appending the results of each iteration to the dictionary you created.

# %%
recommendations={}
customers=data.customerid.unique()

# %%
recommendations[selected_customer] = products_recommended
our_recommendations=pd.DataFrame.from_dict(recommendations,orient='index').reset_index()
columns=['customer','product1','product2','product3','product4','product5']
our_recommendations.columns=columns
our_recommendations.sort_values('customer', inplace=True)
display(our_recommendations)
# Out:
#    customer          product1                      product2  product3  \
# 0        33  Chocolate - Dark  Wine - Charddonnay Errazuriz  Bay Leaf
#
#               product4                       product5
# 0  Oranges - Navel, 72  Wine - Ej Gallo Sierra Valley

# %% [markdown]
# ##  Step 9: Store the results in a Pandas data frame. The data frame should a column for Customer ID and then a column for each of the 5 product recommendations for each customer.

# %%
our_recommendations=pd.DataFrame.from_dict(recommendations,orient='index').reset_index()
columns=['customer','product1','product2','product3','product4','product5']
our_recommendations.columns=columns
our_recommendations.sort_values('customer', inplace=True)
our_recommendations
# Out:
#    customer          product1                      product2  product3  \
# 0        33  Chocolate - Dark  Wine - Charddonnay Errazuriz  Bay Leaf
#
#               product4                       product5
# 0  Oranges - Navel, 72  Wine - Ej Gallo Sierra Valley

# %% [markdown]
# ## Step 10: Change the distance metric used in Step 3 to something other than euclidean (correlation, cityblock, consine, jaccard, etc.). Regenerate the recommendations for all customers and note the differences.

# %%
def RecommenderSystem(calc_type: str):
    print(f'RECOMMENDATIONS USING {calc_type.upper()}')
    dist_eucl = 1 / (1 + squareform(pdist(product_customer, metric=calc_type)))
    distance = pd.DataFrame(dist_eucl, index=product_customer.index, columns=product_customer.index)
          
    for customer in customers:
        similar = distance[customer].sort_values(ascending = False)[1:6]
        similar_ids = similar.index.to_list()
        similarproducts = totalq[totalq.customerid.isin(similar_ids)]
        rankedproducts = similarproducts.groupby('productname', as_index=False)['quantity'].sum().sort_values(by = 'quantity', ascending=False)
        customer_purchases = totalq[['productname','quantity']][totalq['customerid']==customer]
        customer_purchases = [a[1][0] for a in customer_purchases.iterrows()]
        products_to_recommend = rankedproducts[['productname','quantity']]
        products_to_recommend = [a[1][0] for a in products_to_recommend.iterrows()]
        products_recommended = [product for product in products_to_recommend if product not in customer_purchases][:5]
        recommendations[customer] = products_recommended
        our_recommendations=pd.DataFrame.from_dict(recommendations,orient='index').reset_index()
        columns=['customer','product1','product2','product3','product4','product5']
        our_recommendations.columns=columns
        our_recommendations.sort_values('customer', inplace=True)
        
    display(our_recommendations)

# %%
RecommenderSystem('cityblock')
# Out:
# RECOMMENDATIONS USING CITYBLOCK
#      customer                         product1  \
# 0          33                 Chocolate - Dark
# 392       200     Soup - Campbells Bean Medley
# 150       264         Cheese - Parmesan Grated
# 832       356            Veal - Inside, Choice
# 129       412    Wine - Blue Nun Qualitatswein
# ..        ...                              ...
# 307     97928                 Salsify, Organic
# 524     98069        Beef - Texas Style Burger
# 697     98159  Muffin - Carrot Individual Wrap
# 93      98185           Pants Custom Dry Clean
# 162     98200    Wine - Blue Nun Qualitatswein
#
#                             product2                         product3  \
# 0       Wine - Charddonnay Errazuriz                         Bay Leaf
# 392                          Pomello                         Bay Leaf
# 150                    Pork - Kidney               Crush - Cream Soda
# 832     Cup - Translucent 7 Oz Clear           Pepper - White, Ground
# ...

# %%
RecommenderSystem('correlation')
# Out:
# RECOMMENDATIONS USING CORRELATION
#      customer                      product1  \
# 0          33    Rosemary - Primerba, Paste
# 392       200           Pasta - Orecchiette
# 150       264      Water - Mineral, Natural
# 832       356    Yogurt - Blueberry, 175 Gr
# 129       412        Muffin Mix - Blueberry
# ..        ...                           ...
# 307     97928           Wine - Red, Cooking
# 524     98069  Soup - Canadian Pea, Dry Mix
# 697     98159          Curry Paste - Madras
# 93      98185                 Duck - Breast
# 162     98200     Carbonated Water - Cherry
#
#                               product2                  product3  \
# 0                           Cornflakes         Beef - Short Loin
# 392  Pasta - Cheese / Spinach Bauletti   General Purpose Trigger
# 150                  Chicken - Wieners    Cookie - Dough Variety
# 832           Water - Mineral, Natural   Rum - Mount Gay Eclipes
# 129                  Sprouts - Alfalfa           Crackers - Trio
# ...

# %%
RecommenderSystem('cosine')
# Out:
# RECOMMENDATIONS USING COSINE
#      customer                       product1  \
# 0          33                   Durian Fruit
# 392       200            Pasta - Orecchiette
# 150       264       Water - Mineral, Natural
# 832       356      Tea - Herbal Sweet Dreams
# 129       412  Wine - Vidal Icewine Magnotta
# ..        ...                            ...
# 307     97928            Wine - Red, Cooking
# 524     98069                 Fond - Neutral
# 697     98159           Curry Paste - Madras
# 93      98185             Peas - Pigeon, Dry
# 162     98200       Table Cloth 62x114 White
#
#                               product2                       product3  \
# 0                 Beef - Ground Medium  Bread Crumbs - Japanese Style
# 392           Wine - White Cab Sauv.on                Grouper - Fresh
# 150                  Chicken - Wieners             Pickerel - Fillets
# 832                Chicken - Soup Base                Cream Of Tartar
# ...

# %%
RecommenderSystem('jaccard')
# Out:
# RECOMMENDATIONS USING JACCARD
#      customer                         product1                       product2  \
# 0          33                        Milk - 2%                    Guinea Fowl
# 392       200  Muffin - Carrot Individual Wrap         Beans - Kidney, Canned
# 150       264                    Hersey Shakes                   Sugar - Fine
# 832       356  Bread - Italian Roll With Herbs            Sausage - Breakfast
# 129       412                    Cumin - Whole              Veal - Sweetbread
# ..        ...                              ...                            ...
# 307     97928                   Fenngreek Seed                     Watercress
# 524     98069                   Juice - Orange                   Flour - Teff
# 697     98159                 Mustard Prepared  Ecolab - Lime - A - Way 4/4 L
# 93      98185       Soup V8 Roasted Red Pepper       Nut - Pistachio, Shelled
# 162     98200    Wine - Blue Nun Qualitatswein                      Milk - 1%
#
# ...
